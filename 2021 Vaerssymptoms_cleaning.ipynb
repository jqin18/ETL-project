# %%
import pandas as pd
import sqlalchemy as db


from sqlalchemy import create_engine, inspect

# %%
symptoms_file = "2021vaerssymptoms.csv"

# %%
pwd
# Out:
# '/Users/stellaschubert/Desktop/ETL-project'

# %%
symptoms_df = pd.read_csv(symptoms_file)
symptoms_df
# Out:
#        VAERS_ID                             SYMPTOM1  SYMPTOMVERSION1  \
# 0        916600                            Dysphagia             23.1
# 1        916601                              Anxiety             23.1
# 2        916602                     Chest discomfort             23.1
# 3        916603                            Dizziness             23.1
# 4        916604              Injection site erythema             23.1
# ...         ...                                  ...              ...
# 48105   1113920                     Nasal discomfort             23.1
# 48106   1113920                                 Rash             23.1
# 48107   1113963  Haemophagocytic lymphohistiocytosis             23.1
# 48108   1115045                                Death             23.1
# 48109   1115348                                Death             23.1
#
#                       SYMPTOM2  SYMPTOMVERSION2                 SYMPTOM3  \
# ...

# %%
symptoms_df.drop(columns=['SYMPTOMVERSION1', 'SYMPTOMVERSION2', 'SYMPTOMVERSION3','SYMPTOMVERSION4','SYMPTOMVERSION5'], inplace=True)
symptoms_df.drop_duplicates()
# Out:
#        VAERS_ID                             SYMPTOM1                 SYMPTOM2  \
# 0        916600                            Dysphagia             Epiglottitis
# 1        916601                              Anxiety                 Dyspnoea
# 2        916602                     Chest discomfort                Dysphagia
# 3        916603                            Dizziness                  Fatigue
# 4        916604              Injection site erythema  Injection site pruritus
# ...         ...                                  ...                      ...
# 48105   1113920                     Nasal discomfort             Night sweats
# 48106   1113920                                 Rash          SARS-CoV-2 test
# 48107   1113963  Haemophagocytic lymphohistiocytosis          SARS-CoV-2 test
# 48108   1115045                                Death                      NaN
# 48109   1115348                                Death                      NaN
#
# ...

# %%
symptoms_df.to_csv("ETL-project")

# %%
engine = create_engine('sqlite://',
                       echo = False)

# %%
symptoms_df.to_sql('Symptoms_Data',
               con = engine)

# %%
print(engine.execute("SELECT * FROM Symptoms_Data").fetchmany(10))
# Out:
# [(0, 916600, 'Dysphagia', 'Epiglottitis', None, None, None), (1, 916601, 'Anxiety', 'Dyspnoea', None, None, None), (2, 916602, 'Chest discomfort', 'Dysphagia', 'Pain in extremity', 'Visual impairment', None), (3, 916603, 'Dizziness', 'Fatigue', 'Mobility decreased', None, None), (4, 916604, 'Injection site erythema', 'Injection site pruritus', 'Injection site swelling', 'Injection site warmth', None), (5, 916606, 'Pharyngeal swelling', None, None, None, None), (6, 916607, 'Abdominal pain', 'Chills', 'Sleep disorder', None, None), (7, 916608, 'Diarrhoea', 'Nasal congestion', None, None, None), (8, 916609, 'Vaccination site erythema', 'Vaccination site pruritus', 'Vaccination site swelling', None, None), (9, 916610, 'Rash', 'Urticaria', None, None, None)]

# %%
#import dependecies
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np


data_path = "2021VAERSDATA.csv"

vaers_data = pd.read_csv(data_path,low_memory=False)

vaers_data.head(10)
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600  01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 1    916601  01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 2    916602  01/01/2021    WA     23.0     23.0      NaN   F      NaN
# 3    916603  01/01/2021    WA     58.0     58.0      NaN   F      NaN
# 4    916604  01/01/2021    TX     47.0     47.0      NaN   F      NaN
# 5    916606  01/01/2021    NV     44.0     44.0      NaN   F      NaN
# 6    916607  01/01/2021    KS     50.0     50.0      NaN   M      NaN
# 7    916608  01/01/2021    OH     33.0     33.0      NaN   M      NaN
# 8    916609  01/01/2021    TN     71.0     71.0      NaN   F      NaN
# 9    916610  01/01/2021    VA     18.0     18.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Right side of epiglottis swelled up and hinder...  NaN  ...
# 1  Approximately 30 min post vaccination administ...  NaN  ...
# ...

# %%
#getting rid of columns that is not needed
vaers_data = vaers_data[["VAERS_ID", "RECVDATE", "STATE", "AGE_YRS", "SEX", "SYMPTOM_TEXT", "RECOVD", "ALLERGIES" ]]
vaers_data.head(10)
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS SEX  \
# 0    916600  01/01/2021    TX     33.0   F
# 1    916601  01/01/2021    CA     73.0   F
# 2    916602  01/01/2021    WA     23.0   F
# 3    916603  01/01/2021    WA     58.0   F
# 4    916604  01/01/2021    TX     47.0   F
# 5    916606  01/01/2021    NV     44.0   F
# 6    916607  01/01/2021    KS     50.0   M
# 7    916608  01/01/2021    OH     33.0   M
# 8    916609  01/01/2021    TN     71.0   F
# 9    916610  01/01/2021    VA     18.0   F
#
#                                         SYMPTOM_TEXT RECOVD  \
# 0  Right side of epiglottis swelled up and hinder...      Y
# 1  Approximately 30 min post vaccination administ...      Y
# 2  About 15 minutes after receiving the vaccine, ...      U
# 3  extreme fatigue, dizziness,. could not lift my...      Y
# 4  Injection site swelling, redness, warm to the ...      N
# 5  patient called back the next day and stated he...      Y
# 6  SEVERE chills approximately 13-14 hours after ...      Y
# ...

# %%
#check the counts to each column
vaers_data.count()
# Out:
# VAERS_ID        34121
# RECVDATE        34121
# STATE           28550
# AGE_YRS         30933
# SEX             34121
# SYMPTOM_TEXT    34119
# RECOVD          31264
# ALLERGIES       18587
# dtype: int64

# %%
#found out 50% of the allergies column has none or NAN, not dropping it because it loses too much info
vaers_data['ALLERGIES'].value_counts(ascending = True)
# Out:
# Patient reports allergies to Vicodin, Percocet, Dilaudid, Benzoyl Peroxide, Dramamine, Iodine, silk tape, and lanolin.       1
# IVP dye Latex Bananas  Pineapple                                                                                             1
# latex, cherries, peaches                                                                                                     1
# ACE inhibitors, ARBs                                                                                                         1
# NoNe                                                                                                                         1
#                                                                                                                           ...
# Penicillin                                                                                                                 361
# ...

# %%
#will name most of the values NKA, which is a medical abbrevation for "not known allergies"
vaers_data["ALLERGIES"].replace({"NKDA":"NKA", "none":"NKA", "None":"NKA","na":"NKA"})
vaers_data["ALLERGIES"].fillna('NKA', inplace = True)

# %%
#drop na
vaers_data = vaers_data.dropna(how='any')

# %%
#new file
vaers_data.to_csv('vaers_data.csv', encoding='utf-8')
